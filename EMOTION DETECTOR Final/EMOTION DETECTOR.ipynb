# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import cycle
import seaborn as sns

# %%
m

# %%
print(data.shape)
# Out:
# (1782, 5)

# %%
data.head()
# Out:
#    SYSTOLIC_PRESSURE  DIASTOLIC_PRESSURE  HEART_RATE  BLOOD_VISCOSITY  \
# 0              142.0                91.0        83.0         0.401894
# 1                NaN                92.0       113.0         0.364193
# 2              171.0                91.0       104.0         0.381117
# 3              135.0                91.0        83.0         0.346678
# 4              154.0                98.0       116.0         0.392839
#
#      EMOTION
# 0   STRESSED
# 1      ANGRY
# 2      ANGRY
# 3  DEPRESSED
# 4      ANGRY

# %%
data
# Out:
#       SYSTOLIC_PRESSURE  DIASTOLIC_PRESSURE  HEART_RATE  BLOOD_VISCOSITY  \
# 0                 142.0                91.0        83.0         0.401894
# 1                   NaN                92.0       113.0         0.364193
# 2                 171.0                91.0       104.0         0.381117
# 3                 135.0                91.0        83.0         0.346678
# 4                 154.0                98.0       116.0         0.392839
# 5                 125.0                87.0         NaN         0.394807
# 6                 127.0                88.0        88.0         0.398619
# 7                 130.0                90.0        83.0         0.344925
# 8                 175.0                98.0       112.0         0.353194
# 9                 157.0                92.0       102.0         0.361764
# 10                130.0                88.0        77.0         0.390853
# 11                163.0                99.0        98.0         0.397864
# 12                118.0                83.0        63.0         0.339605
# 13                131.0                94.0        77.0         0.305446
# 14                116.0                84.0        66.0         0.323179
# 15                150.0                88.0        89.0         0.409995
# 16                133.0                82.0        83.0         0.376518
# 17                180.0                90.0       107.0         0.383550
# 18                141.0                86.0        83.0         0.336575
# 19                116.0                83.0        65.0         0.337598
# 20                126.0                79.0        68.0         0.326801
# 21                118.0                83.0        76.0         0.323099
# 22                139.0                88.0        77.0         0.379661
# 23                127.0                87.0        83.0         0.385667
# 24                172.0                98.0        96.0         0.367309
# 25                161.0                94.0       115.0         0.377033
# 26                171.0                99.0        99.0         0.391146
# 27                150.0                95.0        82.0         0.340071
# 28                152.0                90.0       109.0         0.383700
# 29                131.0                86.0        74.0         0.380857
# ...                 ...                 ...         ...              ...
# 1752              139.0                86.0        79.0         0.312646
# 1753              153.0                93.0        95.0         0.355125
# 1754              159.0                92.0        77.0         0.309095
# 1755              128.0                86.0        77.0         0.378717
# 1756              147.0                92.0        82.0         0.338464
# 1757              118.0                79.0        75.0         0.333419
# 1758              146.0                93.0        81.0         0.338380
# 1759              121.0                78.0        61.0         0.329783
# 1760              158.0                92.0        83.0         0.416408
# 1761              124.0                86.0        75.0         0.391107
# 1762              148.0                95.0        77.0         0.312452
# 1763              123.0                86.0        82.0         0.371324
# 1764              125.0                90.0        83.0         0.397368
# 1765              140.0                89.0        79.0         0.395445
# 1766              175.0                 NaN       112.0         0.365173
# 1767              125.0                90.0        80.0         0.382316
# 1768              155.0                93.0        80.0         0.317234
# 1769              121.0                79.0        73.0         0.321449
# 1770              121.0                85.0        69.0         0.339146
# 1771              137.0                82.0        80.0         0.379552
# 1772              156.0                95.0        79.0         0.300743
# 1773              127.0                88.0        77.0         0.418028
# 1774              121.0                84.0        70.0         0.326142
# 1775              126.0                81.0        82.0         0.396161
# 1776              140.0                90.0        77.0         0.341209
# 1777              122.0                79.0        62.0         0.330611
# 1778              154.0                89.0        78.0         0.329645
# 1779                NaN                94.0        99.0         0.362319
# 1780              143.0                90.0        64.0         0.398557
# 1781              151.0                89.0        68.0         0.404595
#
#         EMOTION
# 0      STRESSED
# 1         ANGRY
# 2         ANGRY
# 3     DEPRESSED
# 4         ANGRY
# 5           SAD
# 6      STRESSED
# 7     DEPRESSED
# 8         ANGRY
# 9         ANGRY
# 10          SAD
# 11        ANGRY
# 12        HAPPY
# 13    DEPRESSED
# 14        HAPPY
# 15     STRESSED
# 16          SAD
# 17        ANGRY
# 18    DEPRESSED
# 19        HAPPY
# 20        HAPPY
# 21        HAPPY
# 22          SAD
# 23          SAD
# 24        ANGRY
# 25        ANGRY
# 26        ANGRY
# 27    DEPRESSED
# 28        ANGRY
# 29          SAD
# ...         ...
# 1752  DEPRESSED
# 1753      ANGRY
# 1754  DEPRESSED
# 1755        SAD
# 1756  DEPRESSED
# 1757      HAPPY
# 1758  DEPRESSED
# 1759      HAPPY
# 1760   STRESSED
# 1761        SAD
# 1762  DEPRESSED
# 1763        SAD
# 1764        SAD
# 1765        SAD
# 1766      ANGRY
# 1767        SAD
# 1768  DEPRESSED
# 1769      HAPPY
# 1770      HAPPY
# 1771        SAD
# 1772  DEPRESSED
# 1773   STRESSED
# 1774      HAPPY
# 1775        SAD
# 1776  DEPRESSED
# 1777      HAPPY
# 1778  DEPRESSED
# 1779      ANGRY
# 1780   STRESSED
# 1781   STRESSED
#
# [1782 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# SYSTOLIC_PRESSURE     27
# DIASTOLIC_PRESSURE    30
# HEART_RATE            26
# BLOOD_VISCOSITY       19
# EMOTION                0
# dtype: int64

# %%
data.dtypes
# Out:
# SYSTOLIC_PRESSURE     float64
# DIASTOLIC_PRESSURE    float64
# HEART_RATE            float64
# BLOOD_VISCOSITY       float64
# EMOTION                object
# dtype: object

# %%
data['SYSTOLIC_PRESSURE'].mean()
# Out:
# 141.9031339031339

# %%
data['DIASTOLIC_PRESSURE'].mean()
# Out:
# 88.61872146118722

# %%
data['HEART_RATE'].mean()
# Out:
# 81.70785876993166

# %%
data['BLOOD_VISCOSITY'].mean()
# Out:
# 0.3622338361883157

# %%
data['SYSTOLIC_PRESSURE']=data['SYSTOLIC_PRESSURE'].fillna(data['SYSTOLIC_PRESSURE'].mean())

# %%
data['DIASTOLIC_PRESSURE']=data['DIASTOLIC_PRESSURE'].fillna(data['DIASTOLIC_PRESSURE'].mean())

# %%
data['BLOOD_VISCOSITY']=data['BLOOD_VISCOSITY'].fillna(data['BLOOD_VISCOSITY'].mean())

# %%
data['HEART_RATE']=data['HEART_RATE'].fillna(data['HEART_RATE'].mean())

# %%
data.isnull().sum()
# Out:
# SYSTOLIC_PRESSURE     0
# DIASTOLIC_PRESSURE    0
# HEART_RATE            0
# BLOOD_VISCOSITY       0
# EMOTION               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['SYSTOLIC_PRESSURE', 'DIASTOLIC_PRESSURE', 'HEART_RATE',
#        'BLOOD_VISCOSITY', 'EMOTION'],
#       dtype='object')

# %%
sp=data.iloc[:,0].values
dp=data.iloc[:,1].values
hr=data.iloc[:,2].values
bv=data.iloc[:,3].values
emotion=data.iloc[:,4].values

# %%
from sklearn.preprocessing import LabelEncoder
cat_var =data.dtypes.loc[data.dtypes == 'object'].index
le =LabelEncoder()
for var in cat_var:
    data[var] = le.fit_transform(data[var])

# %%
data
# Out:
#       SYSTOLIC_PRESSURE  DIASTOLIC_PRESSURE  HEART_RATE  BLOOD_VISCOSITY  \
# 0            142.000000           91.000000   83.000000         0.401894
# 1            141.903134           92.000000  113.000000         0.364193
# 2            171.000000           91.000000  104.000000         0.381117
# 3            135.000000           91.000000   83.000000         0.346678
# 4            154.000000           98.000000  116.000000         0.392839
# 5            125.000000           87.000000   81.707859         0.394807
# 6            127.000000           88.000000   88.000000         0.398619
# 7            130.000000           90.000000   83.000000         0.344925
# 8            175.000000           98.000000  112.000000         0.353194
# 9            157.000000           92.000000  102.000000         0.361764
# 10           130.000000           88.000000   77.000000         0.390853
# 11           163.000000           99.000000   98.000000         0.397864
# 12           118.000000           83.000000   63.000000         0.339605
# 13           131.000000           94.000000   77.000000         0.305446
# 14           116.000000           84.000000   66.000000         0.323179
# 15           150.000000           88.000000   89.000000         0.409995
# 16           133.000000           82.000000   83.000000         0.376518
# 17           180.000000           90.000000  107.000000         0.383550
# 18           141.000000           86.000000   83.000000         0.336575
# 19           116.000000           83.000000   65.000000         0.337598
# 20           126.000000           79.000000   68.000000         0.326801
# 21           118.000000           83.000000   76.000000         0.323099
# 22           139.000000           88.000000   77.000000         0.379661
# 23           127.000000           87.000000   83.000000         0.385667
# 24           172.000000           98.000000   96.000000         0.367309
# 25           161.000000           94.000000  115.000000         0.377033
# 26           171.000000           99.000000   99.000000         0.391146
# 27           150.000000           95.000000   82.000000         0.340071
# 28           152.000000           90.000000  109.000000         0.383700
# 29           131.000000           86.000000   74.000000         0.380857
# ...                 ...                 ...         ...              ...
# 1752         139.000000           86.000000   79.000000         0.312646
# 1753         153.000000           93.000000   95.000000         0.355125
# 1754         159.000000           92.000000   77.000000         0.309095
# 1755         128.000000           86.000000   77.000000         0.378717
# 1756         147.000000           92.000000   82.000000         0.338464
# 1757         118.000000           79.000000   75.000000         0.333419
# 1758         146.000000           93.000000   81.000000         0.338380
# 1759         121.000000           78.000000   61.000000         0.329783
# 1760         158.000000           92.000000   83.000000         0.416408
# 1761         124.000000           86.000000   75.000000         0.391107
# 1762         148.000000           95.000000   77.000000         0.312452
# 1763         123.000000           86.000000   82.000000         0.371324
# 1764         125.000000           90.000000   83.000000         0.397368
# 1765         140.000000           89.000000   79.000000         0.395445
# 1766         175.000000           88.618721  112.000000         0.365173
# 1767         125.000000           90.000000   80.000000         0.382316
# 1768         155.000000           93.000000   80.000000         0.317234
# 1769         121.000000           79.000000   73.000000         0.321449
# 1770         121.000000           85.000000   69.000000         0.339146
# 1771         137.000000           82.000000   80.000000         0.379552
# 1772         156.000000           95.000000   79.000000         0.300743
# 1773         127.000000           88.000000   77.000000         0.418028
# 1774         121.000000           84.000000   70.000000         0.326142
Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model.predict(x_train)
# Out:
# array([3, 1, 0, ..., 0, 1, 1])

# %%
predicted_train = model.predict(x_train)
true_value = y_train

# %%
predicted_train
# Out:
# array([3, 1, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score
print("Train Accuracy {:.2%}".format(accuracy_score(true_value,predicted_train)))
# Out:
# Train Accuracy 84.87%

# %%
from sklearn.metrics import confusion_matrix,classification_report
print("Classification Report")
print (classification_report(true_value,predicted_train))
print ("Confusion matrix")
print (confusion_matrix(true_value,predicted_train))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       344
#            1       0.95      0.94      0.94       366
#            2       0.89      0.88      0.88       331
#            3       0.67      0.71      0.69       322
#            4       0.83      0.74      0.79       329
#
#    micro avg       0.85      0.85      0.85      1692
#    macro avg       0.85      0.85      0.85      1692
# weighted avg       0.85      0.85      0.85      1692
#
# Confusion matrix
# [[329  12   0   0   3]
#  [  4 343   0  19   0]
#  [  0   3 290  34   4]
#  [ 17   0  33 229  43]
#  [ 16   3   3  62 245]]

# %%
r2_score=model.score(x_train,y_train)

# %%
print(r2_score)
# Out:
# 0.8486997635933806

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(true_value,predicted_train))
print(metrics.mean_squared_error(true_value,predicted_train))
# Out:
# 0.22399527186761228
# 0.4604018912529551

# %%
print(np.sqrt(metrics.mean_squared_error(true_value,predicted_train)))
# Out:
# 0.6785292117904395

# %%
plt.scatter(true_value,predicted_train)

# %%
data=data.drop([], axis=1)
corr=data.corr()
corr
# Out:
#                     SYSTOLIC_PRESSURE  DIASTOLIC_PRESSURE  HEART_RATE  \
# SYSTOLIC_PRESSURE            1.000000            0.704508    0.682024
# DIASTOLIC_PRESSURE           0.704508            1.000000    0.602814
# HEART_RATE                   0.682024            0.602814    1.000000
# BLOOD_VISCOSITY              0.226140            0.312325    0.200625
# EMOTION                     -0.443981           -0.299666   -0.615033
#
#                     BLOOD_VISCOSITY   EMOTION
# SYSTOLIC_PRESSURE          0.226140 -0.443981
# DIASTOLIC_PRESSURE         0.312325 -0.299666
# HEART_RATE                 0.200625 -0.615033
# BLOOD_VISCOSITY            1.000000  0.515124
# EMOTION                    0.515124  1.000000

# %%
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,cmap="YlGnBu",annot=True)

# %%
plt.bar(emotion,sp,color='g')
plt.ylabel('SYSTOLIC_PRESSURE', fontsize=10)
plt.xlabel('EMOTION', fontsize=10)
plt.title('EFFECT OF SYSTOLIC_PRESSURE ON EMOTION')
plt.show()

# %%
plt.bar(emotion,dp,color='r')
plt.ylabel('DIASTOLIC_PRESSURE', fontsize=10)
plt.xlabel('EMOTION', fontsize=10)
plt.title('EFFECT OF DIASTOLIC_PRESSURE ON EMOTION')
plt.show()

# %%
plt.bar(emotion,hr)
plt.ylabel('HEART_RATE', fontsize=10)
plt.xlabel('EMOTION', fontsize=10)
plt.title('EFFECT OF HEART_RATE ON EMOTION')
plt.show()

# %%
plt.bar(emotion,bv,color='y')
plt.ylabel('BLOOD_VISCOSITY', fontsize=10)
plt.xlabel('EMOTION', fontsize=10)
plt.title('EFFECT OF BLOOD_VISCOSITY ON EMOTION')
plt.show()
